# %% [markdown]
# <a href="https://colab.research.google.com/github/Haripolishetty/Deep_Learning_lab/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hari_sai_polishetty_210968168

# %% [markdown]
# Exercise 1:
# Accurate measurement of body fat is inconvenient/costly and it is desirable to have easy methods of predicting Body Fat. Using the Body Fat dataset, write a Neural Network to predict body fat:
# a. Number of Hidden layers = 3 and number of units are 128,64,32
# b. Use RELU activation function, let learning rate be 0.1
# Spit the data into (80,20) split and tabulate the performance in terms of RMSE for100 epochs and comment on performance.
# The attributes of the dataset are :
# 1. Density determined from underwater weighing
# 2. Percent body fat from Siri's (1956) equation
# 3. Age (years)
# 4. Weight (lbs)
# 5. Height (inches)
# 6. Neck circumference (cm)
# 7. Chest circumference (cm)
# 8. Abdomen 2 circumference (cm)
# 9. Hip circumference (cm)
# 10. Thigh circumference (cm)
# 11. Knee circumference (cm)
# 12. Ankle circumference (cm)
# 13. Biceps (extended) circumference (cm)
# 14. Forearm circumference (cm)
# 15. Wrist circumference (cm)

# %% [markdown]
# #importing libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense, Input

# %% [markdown]
# #importing Dataset

# %%
df = pd.read_csv("/content/bodyfat.csv")

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %% [markdown]
# #Defining independent and dependent variables

# %%
x=df.drop('BodyFat',axis=1)
y = df['BodyFat']

# %%
x
# Out:
#      Density  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     1.0708   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3
# 1     1.0853   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3
# 2     1.0414   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9
# 3     1.0751   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3
# 4     1.0340   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2
# ..       ...  ...     ...     ...   ...    ...      ...    ...    ...   ...
# 247   1.0736   70  134.25   67.00  34.9   89.2     83.6   88.8   49.6  34.8
# 248   1.0236   72  201.00   69.75  40.9  108.5    105.0  104.5   59.6  40.8
# 249   1.0328   72  186.75   66.00  38.9  111.1    111.5  101.7   60.3  37.3
# 250   1.0399   72  190.75   70.50  38.9  108.3    101.3   97.8   56.0  41.6
# 251   1.0271   74  207.50   70.00  40.8  112.4    108.5  107.1   59.3  42.2
#
#      Ankle  Biceps  Forearm  Wrist
# 0     21.9    32.0     27.4   17.1
# 1     23.4    30.5     28.9   18.2
# 2     24.0    28.8     25.2   16.6
# 3     22.8    32.4     29.4   18.2
# 4     24.0    32.2     27.7   17.7
# ..     ...     ...      ...    ...
# 247   21.5    25.6     25.7   18.5
# 248   23.2    35.2     28.6   20.1
# 249   21.5    31.3     27.2   18.0
# 250   22.7    30.5     29.4   19.8
# 251   24.6    33.7     30.0   20.9
#
# [252 rows x 14 columns]

# %%
y
# Out:
# 0      12.3
# 1       6.1
# 2      25.3
# 3      10.4
# 4      28.7
#        ...
# 247    11.0
# 248    33.6
# 249    29.3
# 250    26.0
# 251    31.9
# Name: BodyFat, Length: 252, dtype: float64

# %% [markdown]
# #spliting data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.2)
#spliting the data in to 80,20-test size

# %% [markdown]
# #Define the model

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(14,)))#no of features are 14
model.add(Dense(64, activation='relu'))#used Relu function
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='softmax'))
#as mentioned in the question i have used 3 diff units @128,64,32 with 3 hidden layers

# %%
model.summary()
#Disaplaying the model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 12,289
# Trainable params: 12,289
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #compiling the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
from keras import losses
from keras import optimizers
from keras import metrics
#Hari sai polishetty

# %%
model.compile(loss = 'mean_squared_error',
   optimizer =tf.keras.optimizers.Adam(learning_rate=0.1), metrics = [tf.keras.metrics.RootMeanSquaredError()])
#learning rate is 0.1

# %% [markdown]
# #training the model with respective epochs

# %%
model.fit(x_train, y_train, epochs=100,batch_size=32)
#100 epochs
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 6/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 8/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 11/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 22/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 23/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 34/100
# 7/7 [==============================] - 0s 5ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 43/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 46/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 47/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 49/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 53/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 56/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 71/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 73/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3290 - root_mean_squared_error: 19.7820
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 98/100
# 7/7 [==============================] - 0s 4ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 391.3291 - root_mean_squared_error: 19.7820

# %%
from sklearn.metrics import mean_squared_error

# %%
#here i have used the value 10 for softmax which has given me the error

# %%
#Then corrected it with 1

# %%
y_pred= model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
m = tf.keras.metrics.RootMeanSquaredError()
m.update_state( y_test,y_pred)
print('Root mean squared error:',float(m.result()))
# Out:
# Root mean squared error: 20.742862701416016

# %%
# Here i have used Root mean squared error

# %%
y_test.shape
# Out:
# (51,)

# %%
y_pred.shape
# Out:
# (51, 1)

# %% [markdown]
# #Evaluating the model

# %%
m = tf.keras.metrics.MeanSquaredError()
m.update_state( y_test,y_pred)
print(' mean squared error:',float(m.result()))
# Out:
#  mean squared error: 430.2663269042969

# %%
# i have also used mean sqaured error here

# %%
'''
*Developed a model to predict body fat with following features.
*using Rmse the model has given the result of 18.2 and with Mse 332.25
*updation of model could give better prediction.
'''
# Out:
# '\n*Developed a model to predict body fat with following features.\n*using Rmse the model has given the result of 18.2 and with Mse 332.25\n*updation of model could give better prediction.\n'
